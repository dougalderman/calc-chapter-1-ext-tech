# %%
x = var('x')

# %%
y3=0.781*x + 2.036e-4*x^2 - 4.526e-6*x^3 + 4.605

# %%
d3 = derivative(y3, x)

# %%
d3
# Out:
# -0.0000135780000000000*x^2 + 0.000407200000000000*x + 0.781000000000000

# %%
plot(y3, (x,0,500))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(d3, (x,0,500))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
eq3 = -0.0000135780000000000*x^2 + 0.000407200000000000*x + 0.781000000000000 == 0

# %%
eq3.find_root(240, 260)
# Out:
# 255.2954110389768

# %%
def f3(x): return 0.781*x + 2.036e-4*x^2 - 4.526e-6*x^3 + 4.605

# %%
f3(255.295411)
# Out:
# 141.952071370408

# %%
y4=0.815*x - 2.632e-4*x^2 - 2.611e-6*x^3 -2.407e-9*x^4 + 4.303

# %%
d4=derivative(y4, x)

# %%
d4
# Out:
# -(9.62800000000000e-9)*x^3 - (7.83300000000000e-6)*x^2 - 0.000526400000000000*x + 0.815000000000000

# %%
plot(y4,(x,0,500))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(d4, (x,0,500))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
eq4 = -(9.62800000000000e-9)*x^3 - (7.83300000000000e-6)*x^2 - 0.000526400000000000*x + 0.815000000000000 == 0

# %%
eq4.find_root(240, 280)
# Out:
# 256.8330696831798

# %%
def f4(x): return 0.815*x - 2.632e-4*x^2 - 2.611e-6*x^3 -2.407e-9*x^4 + 4.303

# %%
f4(256.83306968)
# Out:
# 141.552864585275

# %%
y_cf = 0.0015*x*(sqrt(202500-x^2))

# %%
d_cf = derivative(y_cf, x)

# %%
d_cf
# Out:
# -0.00150000000000000*x^2/sqrt(-x^2 + 202500) + 0.00150000000000000*sqrt(-x^2 + 202500)

# %%
plot(y_cf, (x,0,500))
# Out:
# verbose 0 (3839: plot.py, generate_plot_points) WARNING: When plotting, failed to evaluate function at 21 points.
# verbose 0 (3839: plot.py, generate_plot_points) Last error message: 'math domain error'
# Graphics object consisting of 1 graphics primitive

# %%
plot(y_cf, (x,0,450))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(d_cf, (x,300,400))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
def f_cf(x): return 0.0015*x*(sqrt(202500-x^2))

# %%
for a in [400, 400.1, 400.2, .., 470]:
    print(a, f_cf(a))
# Out:
# 400.000000000000 123.693168768530
# 400.100000000000 123.607576437085
# 400.200000000000 123.521786726862
# 400.300000000000 123.435799138790
# 400.400000000000 123.349613171434
# 400.500000000000 123.263228320977
# 400.600000000000 123.176644081207
# 400.700000000000 123.089859943497
# 400.800000000000 123.002875396791
# 400.900000000000 122.915689927583
# 401.000000000000 122.828303019907
# 401.100000000000 122.740714155311
# 401.200000000000 122.652922812848
# 401.300000000000 122.564928469052
# 401.400000000000 122.476730597924
# 401.500000000000 122.388328670913
# 401.600000000000 122.299722156898
# 401.699999999999 122.210910522170
# 401.799999999999 122.121893230414
# 401.899999999999 122.032669742688
# 401.999999999999 121.943239517409
# 402.099999999999 121.853602010330
# 402.199999999999 121.763756674523
# 402.299999999999 121.673702960360
# 402.399999999999 121.583440315491
# 402.499999999999 121.492968184828
# 402.599999999999 121.402286010522
# ...

# %%
eq_cf = -0.00150000000000000*x^2/sqrt(-x^2 + 202500) + 0.00150000000000000*sqrt(-x^2 + 202500) == 0

# %%
eq_cf.find_root(300, 340)
# Out:
# 318.1980515339464

# %%
f_cf(318.1980515)
# Out:
# 151.875000000000
